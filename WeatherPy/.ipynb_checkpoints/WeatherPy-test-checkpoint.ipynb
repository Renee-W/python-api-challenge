# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#api.openweathermap.org/data/2.5/weather?q=broome&appid=93a1b7a56ffa925f17f9c3d79187a182
#print(weather_api_key)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %%
#cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units='imperial'

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# # set up lists to hold reponse info
lat = []
temp = []
lon = []
temp_max = []
humidity = []
clouds = []
speed = []
country = []
date = []
weather_city=[]


for city in cities:
    weather_response = requests.get(query_url + city).json()
    
    try:
        lat.append(weather_response['coord']['lat'])
        lon.append(weather_response['coord']['lon'])
        temp.append(weather_response['main']['temp'])
        temp_max.append(weather_response ['main']['temp_max'])
        humidity.append(weather_response ['main']['humidity'])
        clouds.append(weather_response ['clouds']['all'])
        speed.append(weather_response ['wind']['speed'])
        country.append(weather_response ['sys']['country'])
        date.append(weather_response ['dt'])
        weather_city.append(city)
        print(f"processing {city}")
        
    except(KeyError):
        print('missing field skip')
# Out:
# processing baykalsk
# processing aswan
# processing cape town
# processing punta arenas
# processing itarema
# processing ushuaia
# processing busselton
# processing zaria
# processing dzaoudzi
# processing cherskiy
# processing tasiilaq
# processing garissa
# processing khatanga
# processing lagoa
# processing dikson
# processing ancud
# processing grindavik
# processing richards bay
# processing san mateo del mar
# processing kalabo
# processing mataura
# processing yellowknife
# processing port lincoln
# processing nome
# processing albany
# processing angoram
# processing torbay
# processing surab
# processing rikitea
# processing vaini
# processing poso
# processing sabang
# processing kharp
# processing roma
# processing bilibino
# processing puerto ayora
# processing bredasdorp
# processing airai
# missing field skip
# missing field skip
# processing hermanus
# processing castro
# processing kimbe
# missing field skip
# processing shyryayeve
# processing uusikaupunki
# processing kisangani
# processing port moresby
# processing qaanaaq
# processing camacha
# missing field skip
# processing samarai
# processing hasaki
# processing waw
# processing chokurdakh
# processing komsomolskiy
# processing kapaa
# processing sao filipe
# processing arica
# processing aasiaat
# processing santa ana
# missing field skip
# processing hakui
# processing san ignacio
# processing bluff
# missing field skip
# processing stejaru
# missing field skip
# processing miri
# processing clyde river
# processing cabo san lucas
# processing jamestown
# processing nizhnyaya omka
# processing klaksvik
# processing skibbereen
# processing veraval
# processing viedma
# processing barrow
# processing vuktyl
# processing victoria
# processing acapulco
# missing field skip
# processing kangaatsiaq
# processing san miguel
# processing tignere
# processing nikolskoye
# processing avarua
# processing hofn
# processing evensk
# processing bethel
# processing sajanan
# processing hualmay
# processing kodiak
# processing hilo
# processing minden
# processing pevek
# processing tiarei
# processing pangody
# processing hobart
# processing katherine
# processing mar del plata
# processing meulaboh
# processing vila velha
# processing oyama
# missing field skip
# processing bereda
# processing zurrieq
# processing dauphin
# processing hithadhoo
# processing bengkulu
# processing port alfred
# processing karratha
# missing field skip
# processing cockburn town
# processing georgetown
# processing butaritari
# processing suntar
# processing middle island
# processing geraldton
# processing kirakira
# processing santa cruz do sul
# processing dakar
# processing ostrovnoy
# processing pacific grove
# missing field skip
# processing iqaluit
# processing javanrud
# processing thompson
# processing sanghar
# processing mount pleasant
# processing amnat charoen
# processing lebu
# processing upernavik
# processing redcar
# missing field skip
# processing port elizabeth
# missing field skip
# processing hamilton
# processing beyneu
# processing auki
# processing mahebourg
# processing oranjestad
# processing tual
# processing tuktoyaktuk
# processing jinxi
# processing najran
# processing rocky mountain house
# processing bandrele
# processing souillac
# processing bonavista
# processing saratovskaya
# processing sitka
# processing botwood
# processing hof
# processing vilyuysk
# processing ribeira grande
# processing yar-sale
# processing chuguyevka
# processing yima
# processing pitimbu
# processing puerto ayacucho
# processing praia
# processing sao miguel do araguaia
# processing orlik
# processing flin flon
# missing field skip
# processing mananara
# processing acari
# processing bowen
# processing krasnoturansk
# processing laguna
# processing longyearbyen
# processing san luis
# processing bambous virieux
# processing touros
# missing field skip
# processing khadyzhensk
# processing tuatapere
# processing chapais
# processing san patricio
# processing saint-philippe
# processing bobo dioulasso
# processing jiaocheng
# processing esperance
# processing dotnuva
# processing biloela
# processing new norfolk
# processing pisco
# processing mwinilunga
# processing bafra
# missing field skip
# processing lata
# processing marawi
# processing miles city
# processing spirit river
# processing jalu
# processing atuona
# missing field skip
# processing saldanha
# processing nishihara
# processing saint-augustin
# processing palestina
# processing severo-kurilsk
# processing pucara
# processing etampes
# processing alice springs
# processing banyo
# processing gizo
# processing kavieng
# processing necochea
# processing talakan
# processing salalah
# processing chaozhou
# processing namatanai
# processing kununurra
# processing kenai
# processing kruisfontein
# processing soyo
# processing turbat
# processing hashtrud
# processing bouloupari
# processing rawson
# processing labuan
# processing kindu
# processing chifeng
# processing bukachacha
# processing saint george
# processing iisalmi
# processing curuguaty
# processing smithers
# processing alghero
# processing rosaryville
# processing hambantota
# processing ouesso
# processing urusha
# processing chuy
# processing half moon bay
# processing san pedro
# processing xudat
# missing field skip
# processing forestville
# processing carnarvon
# processing batemans bay
# processing jumla
# processing sao jose da coroa grande
# processing ponta do sol
# processing santa cruz de la palma
# processing grand-santi
# processing acarau
# processing faanui
# processing morondava
# processing bandarbeyla
# processing chenghai
# processing harper
# processing tete
# processing faya
# processing catuday
# missing field skip
# processing talnakh
# processing katangli
# processing huilong
# processing talara
# processing narsaq
# processing nagykanizsa
# processing ixtapa
# processing aklavik
# missing field skip
# processing nsanje
# missing field skip
# processing palmer
# processing kibala
# missing field skip
# processing buraydah
# processing baykit
# processing yulara
# processing fortuna
# processing mackay
# processing saskylakh
# processing jieshi
# processing songea
# processing plainview
# processing asau
# processing san felipe
# processing ujjain
# missing field skip
# processing helong
# processing brigantine
# processing cidreira
# processing flinders
# processing laurel
# processing vestmannaeyjar
# processing ulaangom
# processing nizhnyaya tavda
# processing broken hill
# processing mikhaylovka
# processing tabou
# processing beringovskiy
# processing tiznit
# missing field skip
# processing tilichiki
# processing baruun-urt
# processing ukiah
# missing field skip
# missing field skip
# processing norman wells
# processing bonfim
# processing lamu
# processing arman
# processing san policarpo
# missing field skip
# processing mandera
# processing kangaba
# processing sunrise manor
# processing santa maria da vitoria
# missing field skip
# processing emerald
# processing singarayakonda
# processing east london
# processing kaitangata
# processing bairiki
# processing kutum
# processing dunedin
# processing koungou
# processing sakakah
# processing la ronge
# processing tamasopo
# processing niamey
# processing pangkalanbuun
# processing horta
# processing havelock
# processing itororo
# processing mosquera
# missing field skip
# processing stutterheim
# processing abu samrah
# processing rio cuarto
# missing field skip
# processing dayong
# processing leningradskiy
# processing boksitogorsk
# processing oda
# processing poronaysk
# processing matamoros
# processing xinzhou
# processing kytmanovo
# processing shu
# processing trail
# processing luderitz
# processing bay roberts
# processing srandakan
# processing llanes
# processing biograd na moru
# processing lumby
# processing eldorado
# processing glenwood springs
# processing deputatskiy
# processing codrington
# missing field skip
# processing nemuro
# processing xining
# processing luganville
# processing coihaique
# processing arraial do cabo
# processing kalengwa
# processing shchelkun
# processing sagua la grande
# processing cururupu
# processing el monte
# processing tecpan
# processing chabahar
# processing san andres
# processing da nang
# processing kuala selangor
# processing altay
# processing george
# processing mitu
# processing college
# processing shingu
# missing field skip
# processing aden
# processing vardo
# processing bocas del toro
# processing noumea
# processing tura
# processing raposa
# processing challapata
# processing terrasini
# processing scottsboro
# processing atasu
# processing fort nelson
# processing ilulissat
# missing field skip
# processing sinnamary
# processing sovetskiy
# missing field skip
# processing dwarka
# processing trat
# processing wodonga
# processing lusambo
# processing umm lajj
# processing lazaro cardenas
# processing kyshtovka
# processing jiuquan
# processing annan
# processing naze
# processing mani
# processing maniitsoq
# missing field skip
# processing inuvik
# processing jackson
# processing edwardsville
# processing luena
# processing petropavlovsk-kamchatskiy
# processing mudanya
# processing paita
# processing qaqortoq
# processing chongwe
# processing padang
# processing elko
# processing namibe
# processing lompoc
# processing wanning
# processing kota kinabalu
# processing yeniseysk
# processing sanandaj
# processing makaryev
# processing lorengau
# processing buchanan
# processing kayes
# processing qasigiannguit
# processing semey
# processing seymour
# processing bowling green
# processing rjukan
# processing mount gambier
# processing solano
# processing mpulungu
# processing gull lake
# processing saint-pierre
# processing northam
# processing wau
# processing salinas
# processing medenychi
# processing marrakesh
# processing huaihua
# processing grootfontein
# processing hoa binh
# processing antofagasta
# missing field skip
# processing karabulak
# processing takoradi
# processing provideniya
# processing gao
# processing vila franca do campo
# processing ravar
# processing lufilufi
# processing vysokogornyy
# processing namwala
# processing pavino
# processing goundam
# processing clarksville
# processing weimar
# processing belaya gora
# processing popondetta
# missing field skip
# processing inirida
# processing price
# processing wewak
# processing magdeburg
# processing andros town
# processing high level
# processing puerto del rosario
# processing zeya
# processing hami
# processing dabola
# processing winnemucca
# processing portobelo
# processing mae hong son
# processing houma
# missing field skip
# processing tiksi
# processing shangrao
# missing field skip
# processing douentza
# processing bathsheba
# processing antalaha
# processing hovd
# missing field skip
# processing olinda
# processing muli
# processing dunga bunga
# processing iracoubo
# processing salvador
# processing vila
# processing te anau
# processing tovuz
# processing santiago de cao
# processing kahului
# processing yeppoon
# processing huarmey
# processing port hawkesbury
# processing porangatu
# processing shenjiamen
# processing isla mujeres
# processing isangel
# processing salgueiro
# processing avera
# processing valley city
# processing velez-malaga
# missing field skip
# processing malakal
# missing field skip
# processing sunnyside
# processing tondano
# processing poum
# processing canutama
# processing nuuk
# processing walvis bay
# processing fairbanks
# processing borogontsy
# processing wattegama
# processing bijapur
# processing linjiang
# processing san cristobal
# processing constitucion
# processing felipe carrillo puerto
# missing field skip
# processing hastings
# processing ransang
# processing caudry
# processing imperial
# processing jinchang
# processing imbituba
# processing siteki
# missing field skip
# missing field skip
# processing uarini
# processing khandyga
# processing zhezkazgan
# processing jawhar
# processing blackwater
# processing bulgan
# processing novyy urengoy
# processing cap malheureux
# processing gat
# processing sale
# processing cocorit
# processing gaoua
# processing bardstown
# processing oban
# processing pangoa
# processing port augusta
# processing sylvan lake
# processing alibag
# processing praya
# processing pangnirtung
# processing santa cruz del sur
# processing banjar
# processing indramayu
# processing changli
# processing ocho rios
# processing gongzhuling
# missing field skip
# processing essex
# processing marienburg
# processing panaba
# processing grand gaube
# processing guerrero negro
# processing muhos
# processing stevens point
# processing sobolevo
# processing blairmore
# processing potiskum
# processing betulia
# processing mareeba
# processing saint-denis
# missing field skip
# processing rakitnoye
# processing itacare
# processing barranca
# processing pauini
# processing redlands
# processing gornopravdinsk
# processing aripuana
# processing west bay
# processing xuanzhou
# processing miyako
# processing puerto colombia
# processing katobu
# processing lyss
# processing haines junction
# processing murray bridge
# processing sosnowiec

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create city data frame
city_dict={
    "City":cities,
    "Lat":lat,
    "Lng":lon,
    "Max Temp":temp_max,
    "Humidity":humidity,
    "Cloudiness":clouds,
    "Wind Speed":speed,
    "Country":country,
    "Date":date
}
weather_data = pd.DataFrame.from_dict(city_dict, orient='index')
weather_data=weather_data.transpose()

# %%
# Remove null values
weather_data=weather_data.dropna()
weather_data.to_csv("city_weather.csv", encoding="utf-8", index=False)
weather_data
# Out:
#                City      Lat      Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0          baykalsk  51.5058  104.147     38.1       89        100       1.14
# 1             aswan  24.0934   32.907    74.07       17         20      11.27
# 2         cape town -33.9258  18.4232       70       94         36       1.14
# 3      punta arenas   -53.15 -70.9167     42.8       75         40      20.71
# 4           itarema  -2.9248 -39.9167    75.67       91         42       7.67
# ..              ...      ...      ...      ...      ...        ...        ...
# 541          bulgan  -4.9408  122.528    81.72       78        100       4.72
# 542   novyy urengoy  47.0741   7.3066       36      100          9       3.44
# 543  cap malheureux  60.7522 -137.511     35.6       55        100       9.22
# 544             gat -35.1167  139.267    73.99       29         92       5.01
# 545            sale  50.2868  19.1038    35.01       99        100       9.57
#
#     Country        Date
# 0        RU  1618296035
# 1        EG  1618296035
# 2        ZA  1618295910
# 3        CL  1618296036
# 4        BR  1618296037
# ..      ...         ...
# 541      ID  1618296291
# 542      CH  1618296292
# 543      CA  1618296292
# 544      AU  1618296293
# 545      PL  1618296082
#
# [546 rows x 9 columns]

# %%
weather_update = weather_data[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']].astype(float)
weather_update
# Summary=weather_update.groupby(['Lat']).agg({'Lat':['count', 'mean', 'std', 'min', 'max']})
# Summary
weather_city=weather_data[['City', 'Country', 'Lat', 'Lng']]
weather_combo=pd.merge(weather_city, weather_update, on='Lat', how='inner')
#weather_combo
duplicateweather=weather_combo.loc[weather_combo.duplicated(subset=['City']),'City']
# duplicateweather
#weather_combo.loc[weather_combo['City']=='acapulco']
weather2=weather_combo[weather_combo['City'].isin(duplicateweather)==False]
#len(weather_combo['City'].unique())
#len(weather2['City'].unique())
del weather2['Lng_y']
weather2=weather2.rename(columns={'Lng_x':'Lng'})
weather2
# Out:
#                City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0          baykalsk      RU  51.5058  104.147     38.10      89.0       100.0
# 1             aswan      EG  24.0934   32.907     74.07      17.0        20.0
# 2         cape town      ZA -33.9258  18.4232     70.00      94.0        36.0
# 3      punta arenas      CL   -53.15 -70.9167     42.80      75.0        40.0
# 4           itarema      BR  -2.9248 -39.9167     75.67      91.0        42.0
# ..              ...     ...      ...      ...       ...       ...         ...
# 547          bulgan      ID  -4.9408  122.528     81.72      78.0       100.0
# 548   novyy urengoy      CH  47.0741   7.3066     36.00     100.0         9.0
# 549  cap malheureux      CA  60.7522 -137.511     35.60      55.0       100.0
# 550             gat      AU -35.1167  139.267     73.99      29.0        92.0
# 551            sale      PL  50.2868  19.1038     35.01      99.0       100.0
#
#      Wind Speed          Date
# 0          1.14  1.618296e+09
# 1         11.27  1.618296e+09
# 2          1.14  1.618296e+09
# 3         20.71  1.618296e+09
# 4          7.67  1.618296e+09
# ..          ...           ...
# 547        4.72  1.618296e+09
# 548        3.44  1.618296e+09
# 549        9.22  1.618296e+09
# 550        5.01  1.618296e+09
# 551        9.57  1.618296e+09
#
# [540 rows x 9 columns]

# %%
#weathercount=len(weather2.index)
#weathercount
# Latmean=round((weather2['Lat']).mean(),2)
# Latmean
def q25(x):
    return x.quantile(0.25)
def q50(x):
    return x.quantile(0.5)
def q75(x):
    return x.quantile(0.75)
LatSummary=weather2.agg({'Lat':['count', 'mean', 'std', 'min', q25, q50, q75, 'max']})
LngSummary=weather2.agg({'Lng':['count', 'mean', 'std', 'min', q25, q50, q75, 'max']})
MaxTempSummary=weather2.agg({'Max Temp':['count', 'mean', 'std', 'min', q25, q50, q75, 'max']})
HumiditySummary=weather2.agg({'Humidity':['count', 'mean', 'std', 'min', q25, q50, q75, 'max']})
CloudSummary=weather2.agg({'Cloudiness':['count', 'mean', 'std', 'min', q25, q50, q75, 'max']})
WindSummary=weather2.agg({'Wind Speed':['count', 'mean', 'std', 'min', q25, q50, q75, 'max']})
DateSummary=weather2.agg({'Date':['count', 'mean', 'std', 'min', q25, q50, q75, 'max']})

Weather_Summary = pd.DataFrame({'Lat':[LatSummary],
                               'Lng':[LngSummary],
                               'MaxTemp': [MaxTempSummary],
                               'Humidty':[HumiditySummary],
                               'Cloudiness':[CloudSummary],
                               'Wind':[WindSummary],
                               'Date':[DateSummary]})
Weather_Summary
# Out:
#          Humidity
# count  540.000000
# mean    69.888889
# std     23.831790
# min      6.000000
# q25     58.000000
# q50     75.500000
# q75     88.000000
# max    100.000000

# %%
HumiditySummary

# %% [markdown]
# # Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
weather2
# Out:
#                City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0          baykalsk      RU  51.5058  104.147     38.10      89.0       100.0
# 1             aswan      EG  24.0934   32.907     74.07      17.0        20.0
# 2         cape town      ZA -33.9258  18.4232     70.00      94.0        36.0
# 3      punta arenas      CL   -53.15 -70.9167     42.80      75.0        40.0
# 4           itarema      BR  -2.9248 -39.9167     75.67      91.0        42.0
# ..              ...     ...      ...      ...       ...       ...         ...
# 547          bulgan      ID  -4.9408  122.528     81.72      78.0       100.0
# 548   novyy urengoy      CH  47.0741   7.3066     36.00     100.0         9.0
# 549  cap malheureux      CA  60.7522 -137.511     35.60      55.0       100.0
# 550             gat      AU -35.1167  139.267     73.99      29.0        92.0
# 551            sale      PL  50.2868  19.1038     35.01      99.0       100.0
#
#      Wind Speed          Date
# 0          1.14  1.618296e+09
# 1         11.27  1.618296e+09
# 2          1.14  1.618296e+09
# 3         20.71  1.618296e+09
# 4          7.67  1.618296e+09
# ..          ...           ...
# 547        4.72  1.618296e+09
# 548        3.44  1.618296e+09
# 549        9.22  1.618296e+09
# 550        5.01  1.618296e+09
# 551        9.57  1.618296e+09
#
# [540 rows x 9 columns]

# %%
CityTemp=weather2[['Lat','Max Temp']]
CityHumid=weather2[['Lat','Humidity']]
CityCloud=weather2[['Lat','Cloudiness']]
CityWind=weather2[['Lat','Wind Speed']]

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# CityTemp.plot(kind='scatter', x='Latitude', y='Max Temp (F)', grid=True, figsize=(8,8), title'City Latitude vs.MaxTemp')
# plt.show()
x_axis=CityTemp['Lat']
y_axis=CityTemp['Max Temp']
plt.scatter(x_axis, y_axis, marker="o", facecolors="green", edgecolors="black")
plt.grid(True)
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_axis=CityHumid['Lat']
y_axis=CityHumid['Humidity']
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="green")
plt.grid(True)
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_axis=CityCloud['Lat']
y_axis=CityCloud['Cloudiness']

plt.scatter(x_axis, y_axis, marker="o", facecolors='gray', edgecolors="cyan")
plt.grid(True)
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_axis=CityWind['Lat']
y_axis=CityWind['Wind Speed']

plt.scatter(x_axis, y_axis, marker="o", facecolors='plum', edgecolors="black")
plt.grid(True)
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
weather2
# Out:
#                City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0          baykalsk      RU  51.5058  104.147     38.10      89.0       100.0
# 1             aswan      EG  24.0934   32.907     74.07      17.0        20.0
# 2         cape town      ZA -33.9258  18.4232     70.00      94.0        36.0
# 3      punta arenas      CL   -53.15 -70.9167     42.80      75.0        40.0
# 4           itarema      BR  -2.9248 -39.9167     75.67      91.0        42.0
# ..              ...     ...      ...      ...       ...       ...         ...
# 547          bulgan      ID  -4.9408  122.528     81.72      78.0       100.0
# 548   novyy urengoy      CH  47.0741   7.3066     36.00     100.0         9.0
# 549  cap malheureux      CA  60.7522 -137.511     35.60      55.0       100.0
# 550             gat      AU -35.1167  139.267     73.99      29.0        92.0
# 551            sale      PL  50.2868  19.1038     35.01      99.0       100.0
#
#      Wind Speed          Date
# 0          1.14  1.618296e+09
# 1         11.27  1.618296e+09
# 2          1.14  1.618296e+09
# 3         20.71  1.618296e+09
# 4          7.67  1.618296e+09
# ..          ...           ...
# 547        4.72  1.618296e+09
# 548        3.44  1.618296e+09
# 549        9.22  1.618296e+09
# 550        5.01  1.618296e+09
# 551        9.57  1.618296e+09
#
# [540 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Nweather1=weather2.loc[weather2['Lat']>0]
Sweather1=weather2.loc[weather2['Lat']<0]
Nweather = Nweather1[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']].astype(float)
Sweather = Sweather1[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']].astype(float)

# %%
x_values=Nweather['Lat']
y_values=Nweather['Max Temp']
print(f"The r-squared is: {rvalue**2}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Maximum Tempratures by Latitude in the Northern Hemisphere')
plt.show()
# Out:
# The r-squared is: 0.3490074397031927

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values=Sweather['Lat']
y_values=Sweather['Max Temp']
print(f"The r-squared is: {rvalue**2}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Maximum Tempratures by Latitude in the Southern Hemisphere')
plt.show()
# Out:
# The r-squared is: 0.3490074397031927

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values=Nweather['Lat']
y_values=Nweather['Humidity']
print(f"The r-squared is: {rvalue**2}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Humidity by Latitude in the Northern Hemisphere')
plt.show()
# Out:
# The r-squared is: 0.022722187434587555

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values=Sweather['Lat']
y_values=Sweather['Humidity']
print(f"The r-squared is: {rvalue**2}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Humidity by Latitude in the Southern Hemisphere')
plt.show()
# Out:
# The r-squared is: 0.02038042504941013

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values=Nweather['Lat']
y_values=Nweather['Cloudiness']
print(f"The r-squared is: {rvalue**2}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,55),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness by Latitude in the Northern Hemisphere')
plt.show()
# Out:
# The r-squared is: 0.05771994310651439

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values=Sweather['Lat']
y_values=Sweather['Cloudiness']
print(f"The r-squared is: {rvalue**2}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50, 20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness by Latitude in the Northern Hemisphere')
plt.show()
# Out:
# The r-squared is: 0.037612467462396465

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values=Nweather['Lat']
y_values=Nweather['Wind Speed']
print(f"The r-squared is: {rvalue**2}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Wind Speed by Latitude in the Northern Hemisphere')
plt.show()
# Out:
# The r-squared is: 0.0543954832261545

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values=Sweather['Lat']
y_values=Sweather['Wind Speed']
print(f"The r-squared is: {rvalue**2}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Wind Speed by Latitude in the Southern Hemisphere')
plt.show()
# Out:
# The r-squared is: 0.025512083485631894

# %%
# Out:
#                 City      Lat      Lng Max Temp Humidity Cloudiness  \
# 0           baykalsk  51.5058  104.147     38.1       89        100
# 1              aswan  24.0934   32.907    74.07       17         20
# 2          cape town -33.9258  18.4232       70       94         36
# 3       punta arenas   -53.15 -70.9167     42.8       75         40
# 4            itarema  -2.9248 -39.9167    75.67       91         42
# ..               ...      ...      ...      ...      ...        ...
# 588           katobu     None     None     None     None       None
# 589             lyss     None     None     None     None       None
# 590  haines junction     None     None     None     None       None
# 591    murray bridge     None     None     None     None       None
# 592        sosnowiec     None     None     None     None       None
#
#     Wind Speed Country        Date
# 0         1.14      RU  1618296035
# 1        11.27      EG  1618296035
# 2         1.14      ZA  1618295910
# 3        20.71      CL  1618296036
# 4         7.67      BR  1618296037
# ..         ...     ...         ...
# 588       None    None        None
# 589       None    None        None
# 590       None    None        None
# 591       None    None        None
# 592       None    None        None
#
# [593 rows x 9 columns]
